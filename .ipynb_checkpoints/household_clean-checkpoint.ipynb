# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
import missingno as msno
import seaborn as sns

# %%
import os
path = '/Users/yujiaxie/Desktop/Capstone/'
path
# Out:
# '/Users/yujiaxie/Desktop/Capstone/'

# %%
household_df = pd.read_csv(path+"household/household_data_1min_singleindex.csv",parse_dates=['utc_timestamp'])
timeseries_df = pd.read_csv(path+"timeseries/time_series_15min_singleindex.csv",parse_dates=['utc_timestamp','cet_cest_timestamp'])
weather_df = pd.read_csv(path+"weather/weather_data.csv",parse_dates=['utc_timestamp','cet_cest_timestamp'])
# Out:
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (70) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# household_df.isna().sum()
household = household_df.copy()
# household.columns

# %%
# timeseries_df.isna().sum()
new_timeseries_cL = []
for c in timeseries_df.columns:
    if c[:2] == 'DE' or c in ["utc_timestamp", "cet_cest_timestamp"]:
        new_timeseries_cL.append(c)
timeseries = timeseries_df[new_timeseries_cL]

# %%
# weather_df.isna().sum()
new_weather_cL = []
for c in weather_df.columns:
    if c[:2] == 'DE' or c in ["utc_timestamp"]:
        new_weather_cL.append(c)
weather = weather_df[new_weather_cL]

# %%
weather.columns
# Out:
# Index(['utc_timestamp', 'DE_temperature', 'DE_radiation_direct_horizontal',
#        'DE_radiation_diffuse_horizontal'],
#       dtype='object')

# %% [markdown]
# ## Weather

# %%
def return_time(df):
    return pd.to_datetime(df["utc_timestamp"])
def get_year(df):
    return df.utc_timestamp.year
weather['utc_timestamp'] = weather.apply(return_time, axis = 1)
weather['year'] = weather.apply(get_year, axis = 1)
# Out:
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
weather_2010 = weather[weather['year']>2000]
date = pd.to_datetime(weather_2010["utc_timestamp"])
value = weather_2010["DE_temperature"]
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(date, value);
ax.set_title("DE Temperature after 2000", fontsize = 15)
ax.set_xlabel("year", fontsize = 10)
ax.set_ylabel("temperature", fontsize = 10)
# Out:
# Text(0, 0.5, 'temperature')

# %%
weather_cut = weather[weather['year']>=2019]
date = pd.to_datetime(weather_cut["utc_timestamp"])
value = weather_cut["DE_temperature"]
fig, ax = plt.subplots(figsize=(20, 12))
ax.plot(date, value);
ax.set_title("DE Temperature in 2019", fontsize = 15)
ax.set_xlabel("month", fontsize = 10)
ax.set_ylabel("temperature", fontsize = 10)
# Out:
# Text(0, 0.5, 'temperature')

# %%
# from statsmodels.tsa.seasonal import seasonal_decompose
# from dateutil.parser import parse

# weather_timeseries = weather_2010[['utc_timestamp','DE_temperature']]
# weather_timeseries = weather_timeseries.set_index("utc_timestamp")

# # Additive Decomposition
# add = seasonal_decompose(weather_timeseries['DE_temperature'], model='additive', extrapolate_trend='freq')

# # Plot
# plt.rcParams.update({'figure.figsize': (10,10)})
# add.plot().suptitle('Additive Decompose', fontsize=22)
# plt.show()

# %% [markdown]
# ## Household

# %%
industrial1_cL = ['utc_timestamp', 'cet_cest_timestamp']
industrial2_cL = ['utc_timestamp', 'cet_cest_timestamp']
industrial3_cL = ['utc_timestamp', 'cet_cest_timestamp']
public1_cL = ['utc_timestamp', 'cet_cest_timestamp']
public2_cL = ['utc_timestamp', 'cet_cest_timestamp']
residential1_cL = ['utc_timestamp', 'cet_cest_timestamp']
residential2_cL = ['utc_timestamp', 'cet_cest_timestamp']
residential3_cL = ['utc_timestamp', 'cet_cest_timestamp']
residential4_cL = ['utc_timestamp', 'cet_cest_timestamp']
residential5_cL = ['utc_timestamp', 'cet_cest_timestamp']
residential6_cL = ['utc_timestamp', 'cet_cest_timestamp']
for c in household.columns:
    if 'industrial1' in c:
        industrial1_cL.append(c)
    if 'industrial2' in c:
        industrial2_cL.append(c)
    if 'industrial3' in c:
        industrial3_cL.append(c)
    if 'public1' in c:
        public1_cL.append(c)
    if 'public2' in c:
        public2_cL.append(c)
    if 'residential1' in c:
        residential1_cL.append(c)
    if 'residential2' in c:
        residential2_cL.append(c)
    if 'residential3' in c:
        residential3_cL.append(c)
    if 'residential4' in c:
        residential4_cL.append(c)
    if 'residential5' in c:
        residential5_cL.append(c)
    if 'residential6' in c:
        residential6_cL.append(c)
industrial1 = household[industrial1_cL]
industrial2 = household[industrial2_cL]
industrial3 = household[industrial3_cL]
public1 = household[public1_cL]
public2 = household[public2_cL]
residential1 = household[residential1_cL]
residential2 = household[residential2_cL]
residential3 = household[residential3_cL]
residential4 = household[residential4_cL]
residential5 = household[residential5_cL]
residential6 = household[residential6_cL]

# %%
dirty_household_dfL = [industrial1, industrial2, industrial3,
                      public1, public2,
                      residential1, residential2, residential3, residential4, residential5, residential6]
nameL = ['industrial1', 'industrial2', 'industrial3',
        'public1', 'public2',
        'residential1', 'residential2', 'residential3', 'residential4', 'residential5', 'residential6']

household_dfL = []
for i,df in enumerate(dirty_household_dfL):
    clean_df = df.dropna(subset=[c for c in df.columns if c not in ['utc_timestamp', 'cet_cest_timestamp']], how='all')
    clean_df.name = nameL[i]
    household_dfL.append(clean_df)

# %%
for df in household_dfL:
    print(df.name)
    print(df.shape, df.isna().sum())
# Out:
# industrial1
# (1037256, 5) utc_timestamp                        0
# cet_cest_timestamp                   0
# DE_KN_industrial1_grid_import    51333
# DE_KN_industrial1_pv_1               2
# DE_KN_industrial1_pv_2               2
# dtype: int64
# industrial2
# (851571, 6) utc_timestamp                              0
# cet_cest_timestamp                         0
# DE_KN_industrial2_grid_import         174892
# DE_KN_industrial2_pv                  131613
# DE_KN_industrial2_storage_charge      266446
# DE_KN_industrial2_storage_decharge    266446
# dtype: int64
# industrial3
# (861580, 22) utc_timestamp                               0
# cet_cest_timestamp                          0
# DE_KN_industrial3_area_offices             36
# DE_KN_industrial3_area_room_1              36
# DE_KN_industrial3_area_room_2              36
# DE_KN_industrial3_area_room_3               0
# DE_KN_industrial3_area_room_4               0
# DE_KN_industrial3_compressor               36
# DE_KN_industrial3_cooling_aggregate        36
# DE_KN_industrial3_cooling_pumps            36
# DE_KN_industrial3_dishwasher                6
# DE_KN_industrial3_ev                   235895
# DE_KN_industrial3_grid_import          171064
# DE_KN_industrial3_machine_1                36
# DE_KN_industrial3_machine_2                36
# DE_KN_industrial3_machine_3                36
# DE_KN_industrial3_machine_4                 0
# DE_KN_industrial3_machine_5                 0
# DE_KN_industrial3_pv_facade                36
# DE_KN_industrial3_pv_roof                  36
# DE_KN_industrial3_refrigerator           6844
# DE_KN_industrial3_ventilation              36
# dtype: int64
# public1
# (272928, 3) utc_timestamp                0
# cet_cest_timestamp           0
# DE_KN_public1_grid_import    0
# dtype: int64
# public2
# (67363, 3) utc_timestamp                0
# cet_cest_timestamp           0
# DE_KN_public2_grid_import    0
# dtype: int64
# residential1
# (952288, 8) utc_timestamp                              0
# cet_cest_timestamp                         0
# DE_KN_residential1_dishwasher           1631
# DE_KN_residential1_freezer            178593
# DE_KN_residential1_grid_import             0
# DE_KN_residential1_heat_pump               0
# DE_KN_residential1_pv                      0
# DE_KN_residential1_washing_machine      1587
# dtype: int64
# residential2
# (1496853, 7) utc_timestamp                               0
# cet_cest_timestamp                          0
# DE_KN_residential2_circulation_pump    307503
# DE_KN_residential2_dishwasher          348905
# DE_KN_residential2_freezer             881866
# DE_KN_residential2_grid_import         549029
# DE_KN_residential2_washing_machine      12932
# dtype: int64
# residential3
# (1992581, 10) utc_timestamp                                0
# cet_cest_timestamp                           0
# DE_KN_residential3_circulation_pump          5
# DE_KN_residential3_dishwasher           246839
# DE_KN_residential3_freezer              268726
# DE_KN_residential3_grid_export          639324
# DE_KN_residential3_grid_import         1278422
# DE_KN_residential3_pv                   639325
# DE_KN_residential3_refrigerator         486600
# DE_KN_residential3_washing_machine      159875
# dtype: int64
# residential4
# (1221516, 11) utc_timestamp                              0
# cet_cest_timestamp                         0
# DE_KN_residential4_dishwasher         464382
# DE_KN_residential4_ev                   4310
# DE_KN_residential4_freezer              4315
# DE_KN_residential4_grid_export             0
# DE_KN_residential4_grid_import             6
# DE_KN_residential4_heat_pump          482951
# DE_KN_residential4_pv                      3
# DE_KN_residential4_refrigerator       575736
# DE_KN_residential4_washing_machine    486110
# dtype: int64
# residential5
# (1848161, 6) utc_timestamp                              0
# cet_cest_timestamp                         0
# DE_KN_residential5_dishwasher         435761
# DE_KN_residential5_grid_import             0
# DE_KN_residential5_refrigerator       974367
# DE_KN_residential5_washing_machine    435754
# dtype: int64
# residential6
# (1292049, 9) utc_timestamp                               0
# cet_cest_timestamp                          0
# DE_KN_residential6_circulation_pump        63
# DE_KN_residential6_dishwasher          448412
# DE_KN_residential6_freezer             371316
# DE_KN_residential6_grid_export         290726
# DE_KN_residential6_grid_import             63
# DE_KN_residential6_pv                      64
# DE_KN_residential6_washing_machine     405026
# dtype: int64

# %%
fig, ax = plt.subplots(3,4, figsize=(25, 25))
for df, subplot in zip(household_dfL, ax.flatten()):
    tmp = df.loc[:, ~df.columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]    
    sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'},
            ax=subplot
           );

# %%
tmp = household_dfL[0].loc[:, ~household_dfL[0].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[0].name);

# %%
tmp = household_dfL[1].loc[:, ~household_dfL[1].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[1].name);
#subplot = sns.displot(data=tmp.isna().melt(value_name="missing"),y="variable",hue="missing",multiple="fill",aspect=1.25)\.set(title=household_dfL[1].name);

# %%
tmp = household_dfL[2].loc[:, ~household_dfL[2].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[2].name);

# %%
tmp = household_dfL[3].loc[:, ~household_dfL[3].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[3].name);

# %%
tmp = household_dfL[4].loc[:, ~household_dfL[4].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[4].name);

# %%
tmp = household_dfL[5].loc[:, ~household_dfL[5].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[5].name);

# %%
tmp = household_dfL[6].loc[:, ~household_dfL[6].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[6].name);

# %%
tmp = household_dfL[7].loc[:, ~household_dfL[7].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[7].name);

# %%
tmp = household_dfL[8].loc[:, ~household_dfL[8].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[8].name);

# %%
tmp = household_dfL[9].loc[:, ~household_dfL[9].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[9].name);

# %%
tmp = household_dfL[10].loc[:, ~household_dfL[10].columns.isin(['utc_timestamp', 'cet_cest_timestamp'])]
sns.heatmap(tmp.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'}).set(title=household_dfL[10].name);

# %%
for df in household_dfL:
    df['utc_timestamp'] = df.apply(return_time, axis = 1)
    df['year'] = df.apply(get_year, axis = 1)
# Out:
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yujiaxie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for df in household_dfL:
    date = df["utc_timestamp"]
    cm = plt.get_cmap('gist_rainbow')
    metrics = [c for c in df.columns if c not in ["utc_timestamp", "cet_cest_timestamp","year"]
               and 'grid' not in c and 'charge' not in c and 'pv' not in c]
    if len(metrics) == 0:
        continue
    fig, ax = plt.subplots(figsize=(20, 6))
    color_map = [cm(1.*i/len(metrics)) for i in range(len(metrics))]
    for i,c in enumerate(metrics):
        value = df[c]
        ax.plot(date, value, color = color_map[i], label = c)
    ax.set_title("{} regular consumption".format(df.name), fontsize = 15)
    ax.set_xlabel("timestamp", fontsize = 10)
    ax.set_ylabel("kWh", fontsize = 10)
    ax.legend(loc="upper left")
    plt.show()

# %%
for df in household_dfL:
    date = df["utc_timestamp"]
    cm = plt.get_cmap('gist_rainbow')
    metrics = [c for c in df.columns if c not in ["utc_timestamp", "cet_cest_timestamp","year"]
               and ('grid_export' in c or 'charge' in c or 'pv' in c) and 'grid_import' not in c]
    if len(metrics) == 0:
        continue
    fig, ax = plt.subplots(figsize=(20, 6))
    color_map = [cm(1.*i/len(metrics)) for i in range(len(metrics))]
    for i,c in enumerate(metrics):
        value = df[c]
        ax.plot(date, value, color = color_map[i], label = c)
    ax.set_title("{} special generation/export/consumption".format(df.name), fontsize = 15)
    ax.set_xlabel("timestamp", fontsize = 10)
    ax.set_ylabel("kWh", fontsize = 10)
    ax.legend(loc="upper left")
    plt.show()
